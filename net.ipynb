# %%
style_model = load_net()

# %%
# !wget -q -O 21styles.model https://www.dropbox.com/s/2iz8orqqubrfrpo/21styles.model?dl=1

# %%
user_input = input("Enter number from 1 to 15")

# %%
content_image_path = 'NST/pics/me_for_exp_1.jpg'
style_image_path = 'NST/styles/style_' + user_input + '.jpg'

# %%
make_nst(content_image=content_image, style_image=style_image)

# %%
display(Image.open('example_output.jpg'))
# display(Image.open(content_image_path).resize((300, 300)))
# # display(Image.open(style_image_path).resize((300, 300)))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x684>
